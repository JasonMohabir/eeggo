# %% [markdown]
# # Massaging Gaussian Mixture Model
#
# jtm98
# Created: 10.29.24
#
# $$ X_i \sim r N (\mu,\sigma^2) + (1-r) N (\beta*\mu,\sigma^2) $$
#
# - $X_i$ is cell expression
# - $r$ is a mixture proportion of label $Z_i$
# - $Z_i \in {0,1} $ and represents whether a cell had normal (0) or decreased (1)  expression
# - $\mu$ is the mean of individuals w/normal expression
# - $\beta$ is the enhancer coefficient

# %%
import os
import numpy as np 
from cmdstanpy import cmdstan_path, CmdStanModel

# %%
mixture ="""

// Assessing if beta parameter is inferable 
data {
int<lower=1> N; // number of samples
array[N] real X; // expression in the sample 
}

parameters {
real<lower=0,upper=1> r; // mixture proportion of samples 
real<lower=0.0> sigma; // standard deviation 
real mu; // mean of individuals w/ normal expression
real beta; // enhancer coefficient
}

model {
r ~ beta(2,2); // mixture proportion based on natural scale 
mu ~ normal(0,10); 
beta ~ beta(2,2); // enhancer coefificent should be [0,1]
sigma ~ inv_gamma(1,1); 
for(i in 1:N)
target+= log_sum_exp(log(r)+normal_lpdf(X[i]|mu,sigma),
log(1-r)+normal_lpdf(X[i]|beta*mu,sigma));
}

generated quantities {
array[N] real<lower=0,upper=1> PZi;
for(i in 1:N) {
real LP0=log(r)+normal_lpdf(X[i]|mu,sigma);
real LP1=log(1-r)+normal_lpdf(X[i]|beta*mu,sigma);
PZi[i]=exp(LP0-log_sum_exp(LP0,LP1));
}
}
"""
! mkdir mixture
with open('mixture/mixture.stan', 'w') as f: f.write(mixture) 
! cat mixture/mixture.stan

# %%
mixture = CmdStanModel(stan_file='mixture/mixture.stan')
# Out:
# 21:55:57 - cmdstanpy - INFO - compiling stan file /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/mixture/mixture.stan to exe file /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/mixture/mixture
# 21:56:06 - cmdstanpy - INFO - compiled model executable: /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/mixture/mixture

# %%
pos_expression = 100
neg_expression = 90 
true_beta = neg_expression / pos_expression # true beta value

# Simulate random data 
pos = np.random.normal(100,0.3,50)
neg = np.random.normal(90,0.3,50)
data = {'X' : np.concatenate([pos,neg]), 'N' : 100}
inits = { 'mu': 1, 'sigma': 0.3, 'r': 0.5, 'beta': .5 }

# %%
mixture_fit = mixture.sample(data=data,thin=1,iter_sampling=1000,iter_warmup=50,inits=inits,seed=11051999)
mixture_fit.summary()['Mean']
# Out:
# 21:56:36 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 21:56:37 - cmdstanpy - INFO - CmdStan done processing.
# 21:56:37 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: beta_lpdf: Random variable is -16.1502, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.36777, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0755, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02664, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01178, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00059, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05531, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03033, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.4815, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03391, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02867, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0238, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.129974, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03224, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04037, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00019, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00013, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00467, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02685, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02976, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02732, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00854, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02147, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01257, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03213, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00198, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05942, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01998, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00954, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.332136, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02235, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01838, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02326, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0113, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.203784, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03633, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00178, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06615, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03874, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02056, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03221, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.199618, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00802, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00312, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02682, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00606, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00608, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00431, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01184, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.283585, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00322, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01755, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0238, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0501129, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01948, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0164, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00399, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05257, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0062, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00244, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00261, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02389, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01409, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00564, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.617442, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01344, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02221, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01982, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01259, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04115, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01061, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00674, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07395, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.10762, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00806, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0924344, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01413, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00987, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00228, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00244, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00277, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01713, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01252, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00012, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01851, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00193, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.314877, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0860826, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01822, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.129275, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0292, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0515, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0140875, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00043, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00583, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00006, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00192, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00114, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0687386, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01889, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01083, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.197188, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02506, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04232, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.17243, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.134751, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0119, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.188931, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02306, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01818, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0021, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00148, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00626, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06361, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02496, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03063, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04953, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02018, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06326, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02207, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04501, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05384, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03389, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.160879, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03815, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01508, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00942, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01748, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08398, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00008, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02659, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01265, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03596, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05165, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09572, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00218, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0946, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00499, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.754528, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01829, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02864, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01035, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0079, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.24888, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01666, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01782, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02029, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00195, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00519, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00567, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02474, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01966, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00985, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02844, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05098, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02016, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01874, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00048, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01654, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01723, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.003, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -1.69976, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0796588, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01816, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02868, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04588, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00421, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00185, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0533391, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00342, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0193, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01615, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0002, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00333, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04312, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00479, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01759, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01167, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00217, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03282, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01573, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01382, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0115, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03056, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01166, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.00317697, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04752, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0144375, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04524, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0039826, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0045, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00359, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03069, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.794658, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00836, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01096, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03767, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01291, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01655, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02711, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08521, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06944, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03368, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01755, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.18077, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02292, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00344, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03509, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00971, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02259, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0154824, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0059, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04246, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06474, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01646, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03543, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06284, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01797, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05649, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06083, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00631, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.11907, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0569, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00881, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00583, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00973, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03695, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01702, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02288, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05938, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09121, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04649, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02457, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02772, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04448, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0159, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01666, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01326, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03476, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07489, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00161, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03234, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03479, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07022, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09258, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08101, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.10934, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01364, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05207, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0322, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0407, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03534, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07726, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07339, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01797, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.038, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01388, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09078, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00268, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.11641, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.20083, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.10736, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0368, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02148, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06627, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07837, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06781, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03261, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09578, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09071, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03792, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08151, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05798, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01892, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.11582, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01473, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01896, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07826, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01905, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01913, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.18179, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09764, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09154, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07014, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04024, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.10054, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01239, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08188, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.1055, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04167, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02961, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0511, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03316, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.14137, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00178, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09437, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.13253, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.11048, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00755, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05145, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08198, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02896, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03606, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06118, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00412, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02083, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.085, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06631, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.15244, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08313, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08073, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00806, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.232853, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0422, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06804, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03755, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03979, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0328, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08553, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0878, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.12941, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.216, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.13645, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.08792, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.10389, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.13008, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02053, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.09957, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02394, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00976, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05084, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03149, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06081, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0355, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.17269, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03775, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03251, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.20248, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00053, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.14235, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0676, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.18129, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.12127, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04763, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.19895, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# ...
# 	Exception: beta_lpdf: Random variable is 1.00292, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03938, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02435, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0045, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04495, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02454, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01464, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00784, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00878, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0524, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00717, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0454, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00168, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03588, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02303, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04957, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0425521, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00701, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06975, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05652, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00461, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01083, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00364, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01676, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00423, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03892, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02303, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00429, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.355196, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02806, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01353, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.360735, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03159, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0293789, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01382, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -2.34271, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02642, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0312, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04995, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00423, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04467, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01468, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02509, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01734, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00665, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.59398, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.00662725, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01803, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0037, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -2.41514, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.911265, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01124, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0277, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.096889, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.047945, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02003, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.00262682, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00991, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02324, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01146, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03644, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.07297, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0757614, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01585, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02428, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0142, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01254, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01792, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03658, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04893, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04351, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01478, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00686, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02007, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04641, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01521, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02879, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04952, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.0564, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02514, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01771, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01401, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00258, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.06962, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0219949, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.10439, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 2.00829, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00765, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01772, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01239, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04436, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0637512, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02138, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02761, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.05122, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01329, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.04236, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02109, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.02022, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.205048, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.875306, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.43656, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01503, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.62268, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.03159, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is -0.0263807, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00756, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.01054, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# 	Exception: beta_lpdf: Random variable is 1.00741, but must be in the interval [0, 1] (in 'mixture.stan', line 19, column 0 to column 17)
# Consider re-running with show_console=True if the above output is unclear!
# 21:56:37 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 537 divergent transitions (53.7%)
# 	Chain 2 had 413 divergent transitions (41.3%)
# 	Chain 3 had 642 divergent transitions (64.2%)
# 	Chain 4 had 256 divergent transitions (25.6%)
# 	Use the "diagnose()" method on the CmdStanMCMC object to see further information.
# lp__       -382.865000
# r             0.940178
# sigma         9.557130
# mu           89.785900
# beta          0.709097
#                ...
# PZi[96]       0.933019
# PZi[97]       0.932819
# PZi[98]       0.934001
# PZi[99]       0.930330
# PZi[100]      0.931962
# Name: Mean, Length: 105, dtype: float64

# %%
estimated_beta = mixture_fit.summary().loc['beta']['Mean']
print('Estimated Beta:',estimated_beta)
print('True Beta:',true_beta)
# Out:
# Estimated Beta: 0.709097
# True Beta: 0.9

# %% [markdown]
# # Hierarchical Gaussian Mixture Model with Latent Potency

# %%
stan_code ="""
data {
  int<lower=0> N_control;                  // Number of control samples
  int<lower=0> N_experiment;               // Number of experimental samples
  array[N_control] real y_control;         // Expression levels in control samples
  array[N_experiment] real y_experiment;   // Expression levels in experimental samples
  array[N_experiment] int<lower=1, upper=5> guide; // Guide index for each experiment sample (1 to 5)
  array[N_experiment] real enhancer;       // Enhancer index for each experiment sample
}

transformed data {
  real<lower=0> mu_control_observed = mean(y_control);            // Empirical mean of y_control
  real<lower=0> sigma_control_observed = sd(y_control);           // Empirical standard deviation of y_control
  real<lower=0> mu_experiment_observed = mean(y_experiment);      // Empirical mean of y_experiment
  real<lower=0> sigma_experiment_observed = sd(y_experiment);     // Empirical standard deviation of y_experiment
  real<lower=0> beta_observed = mu_experiment_observed / mu_control_observed ;   // Empirical effect size 
}

parameters {
  real<lower=0> mu_control;                // Mean expression in control condition
  real<lower=0, upper=1> B;                // Effect size for potent guides
  real<lower=0> sigma_control;             // Standard deviation in control condition
  real<lower=0> sigma_experiment;          // Standard deviation in experiment condition
  array[5] real<lower=0, upper=1> potency; // Potency for each guide (0 to 1)
}

transformed parameters {
  real mu_experiment;                      // Single mu_experiment for all experimental samples
  
  // Mean expression in potent experimental samples
  mu_experiment = B * mu_control;
}

model {
  // Priors based on provided initial values
  mu_control ~ normal(mu_control_observed, sigma_control_observed);        // Prior for control mean centered around 22,000
  B ~ normal(beta_observed, 0.25);                          // Prior for effect size B around 0.5
  sigma_control ~ cauchy(sigma_control_observed, 2);      // Prior for control standard deviation centered around 4,000
  sigma_experiment ~ cauchy(sigma_experiment_observed, 2);   // Prior for experimental standard deviation centered around 3,700
  potency ~ beta(0.5, 0.5);                    // Prior for potency of each guide, allowing flexibility

  // Likelihoods
  y_control ~ normal(mu_control, sigma_control); // Control samples from control distribution

  // Experimental samples based on guide potency
  for (n in 1:N_experiment) {
    real mean_expr = (1 - potency[guide[n]]) * mu_control + potency[guide[n]] * mu_experiment;
    y_experiment[n] ~ normal(mean_expr, sigma_experiment);
  }
}
"""
name = 'model2'
! mkdir {name}
with open('%s/%s.stan'%(name,name), 'w') as f: f.write(stan_code) 
! cat {name}/{name}.stan
# Out:
# mkdir: model2: File exists
#
# data {
#   int<lower=0> N_control;                  // Number of control samples
#   int<lower=0> N_experiment;               // Number of experimental samples
#   array[N_control] real y_control;         // Expression levels in control samples
#   array[N_experiment] real y_experiment;   // Expression levels in experimental samples
#   array[N_experiment] int<lower=1, upper=5> guide; // Guide index for each experiment sample (1 to 5)
# }
#
# transformed data {
#   real<lower=0> mu_control_observed = mean(y_control);            // Empirical mean of y_control
#   real<lower=0> sigma_control_observed = sd(y_control);           // Empirical standard deviation of y_control
#   real<lower=0> mu_experiment_observed = mean(y_experiment);      // Empirical mean of y_experiment
#   real<lower=0> sigma_experiment_observed = sd(y_experiment);     // Empirical standard deviation of y_experiment
#   real<lower=0> beta_observed = mu_experiment_observed / mu_control_observed ;   // Empirical effect size
# }
#
# parameters {
#   real<lower=0> mu_control;                // Mean expression in control condition
#   real<lower=0, upper=1> B;                // Effect size for potent guides
#   real<lower=0> sigma_control;             // Standard deviation in control condition
#   real<lower=0> sigma_experiment;          // Standard deviation in experiment condition
#   array[5] real<lower=0, upper=1> potency; // Potency for each guide (0 to 1)
# }
#
# transformed parameters {
#   real mu_experiment;                      // Single mu_experiment for all experimental samples
#
#   // Mean expression in potent experimental samples
#   mu_experiment = B * mu_control;
# }
#
# model {
#   // Priors based on provided initial values
#   mu_control ~ normal(mu_control_observed, sigma_control_observed);        // Prior for control mean centered around 22,000
#   B ~ normal(beta_observed, 0.25);                          // Prior for effect size B around 0.5
#   sigma_control ~ cauchy(sigma_control_observed, 2);      // Prior for control standard deviation centered around 4,000
#   sigma_experiment ~ cauchy(sigma_experiment_observed, 2);   // Prior for experimental standard deviation centered around 3,700
#   potency ~ beta(0.5, 0.5);                    // Prior for potency of each guide, allowing flexibility
#
#   // Likelihoods
#   y_control ~ normal(mu_control, sigma_control); // Control samples from control distribution
#
#   // Experimental samples based on guide potency
#   for (n in 1:N_experiment) {
#     real mean_expr = (1 - potency[guide[n]]) * mu_control + potency[guide[n]] * mu_experiment;
#     y_experiment[n] ~ normal(mean_expr, sigma_experiment);
#   }
# }

# %%
model = CmdStanModel(stan_file='%s/%s.stan'%(name,name))
# Out:
# 23:16:13 - cmdstanpy - INFO - compiling stan file /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/model2/model2.stan to exe file /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/model2/model2
# 23:16:23 - cmdstanpy - INFO - compiled model executable: /Users/jasonmohabir/Documents/Duke/Courses/GraphicalModels/final_project/model2/model2

# %%
import pandas as pd 

final_data = pd.read_csv("final/data1.tsv",sep='\t')
geneID, enhancerID = 1,1
data_subset = final_data[final_data.geneID == geneID]

control_samples = data_subset[data_subset.enhancerID == -1 ]
N_control = control_samples.shape[0]

# Calculating gene-enhancer B_{gene=1,enhancer=1}
experiment_samples = data_subset[data_subset.enhancerID == enhancerID]
N_experiment = experiment_samples.shape[0]

y_control = control_samples.expression.values
y_experiment = experiment_samples.expression.values
guide = experiment_samples.guideID.values
guide = guide - min(guide) + 1

# %%
data_subset
# Out:
#      geneID  enhancerID  guideID  cellID  expression
# 0         1          -1       -1       1       25763
# 1         1          -1       -1       2       19388
# 2         1          -1       -1       3       17405
# 3         1          -1       -1       4       29517
# 4         1          -1       -1       5       17733
# ..      ...         ...      ...     ...         ...
# 775       1           5       25     776        7725
# 776       1           5       25     777        8098
# 777       1           5       25     778        5885
# 778       1           5       25     779        6509
# 779       1           5       25     780        4842
#
# [780 rows x 5 columns]

# %%
# import data 

# data {
#   int<lower=0> N_control;                  // Number of control samples
#   int<lower=0> N_experiment;               // Number of experimental samples
#   array[N_control] real y_control;         // Expression levels in control samples
#   array[N_experiment] real y_experiment;   // Expression levels in experimental samples
#   array[N_experiment] int<lower=1> guide; // Guide index for each experiment sample (1 to 5)
# }

data = {'N_control': N_control,
        'N_experiment': N_experiment,
        'y_control': y_control,
        'y_experiment': y_experiment,
        'guide': guide ,
        }

# %%
model_fit = model.sample(data=data,thin=1,iter_sampling=1000,iter_warmup=50,seed=11051999)

# %%
model_fit.summary().Mean.to_dict()
# Out:
# {'lp__': -1571.45,
#  'mu_control': 20905.2,
#  'B': 0.887274,
#  'sigma_control': 4537.78,
#  'sigma_experiment': 3780.78,
#  'potency[1]': 0.63098,
#  'potency[2]': 0.17178,
#  'potency[3]': 0.462607,
#  'potency[4]': 0.578569,
#  'potency[5]': 0.487273,
#  'mu_experiment': 18531.1304}
